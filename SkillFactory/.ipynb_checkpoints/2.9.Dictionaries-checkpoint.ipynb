# %%
2.9 Что такое словарь?

Для работы с такими структурами подходят словари. 
Отличаются они от списков тем, что элементом словаря является не одно, а два значения. 
Первое называется ключом, второе — значением. Пример простого словаря из одной такой пары:

employee_base = {'Мария Никитина': '+79033923029'}
В данном случае имя сотрудника — это ключ (располагается слева от двоеточия), 
а номер телефона — значение (соответственно, располагается справа от двоеточия).

Элементы словаря добавляются в него через запятую. Добавим еще одного сотрудника в словарь:

employee_base = {
    'Мария Никитина': '+79033923029',
    'Егор Савичев': '+78125849204',
}

# %%
employee_base = {'Мария Никитина': '+79033923029'}
employee_base
# Out:
# {'Мария Никитина': '+79033923029'}

# %%
#Создайте телефонную книгу в виде словаря
#Добавьте в словарь employee_base оставшиеся контакты (Александра Пахомова, Алины Егоровой и Руслана Башарова)

employee_base = {
    'Мария Никитина': '+79033923029',
    'Егор Савичев': '+78125849204',
    'Александр Пахомов': '+79053049385',
    'Алина Егорова': '+79265748370',
    'Руслан Башаров': '+79030598495'
}
print(employee_base)
print(employee_base['Мария Никитина'])

#Теперь мы можем узнать номер телефона сотрудника, просто обратившись к словарю employee_base 
#по любому из имеющихся ключей (т. е. по имени сотрудника):
#print(employee_base['Мария Никитина'])
#Out: +79033923029
#Теперь нам не нужно искать нужное имя среди всего набора, как это было в случае списков.
# Out:
# {'Мария Никитина': '+79033923029', 'Егор Савичев': '+78125849204', 'Александр Пахомов': '+79053049385', 'Алина Егорова': '+79265748370', 'Руслан Башаров': '+79030598495'}
# +79033923029

# %%
По словарю можно быстро искать

Словари обладают еще одним замечательным свойством: 
в большинстве случаев, время поиска по ключам словаря не зависит от размера словаря. 
То есть поиск по словарю из 100 сотрудников будет занимать почти такое же время, как и по словарю из 100 тысяч сотрудников. 
И происходить это будет гораздо быстрее, чем перебор элементов аналогичного списка.

Дополнительные материалы:
Более подробно про устройство словарей в Python на Хабр: https://habr.com/ru/post/247843/

# %%
#Телефон сотрудника
#Выведите на экран телефон Алины Егоровой, обратившись к соответствующему ключу словаря employee_base из прошлого шага. 
#Для корректной онлайн-проверки не выводите на экран другие значения

print(employee_base['Алина Егорова'])
# Out:
# +79265748370

# %%
#Правильно работает только если явно описывать словарь employee_base.
#На хуя тогда пишете "из прошлого шага"? КРЕТИНЫ, БЛЯДЬ.

employee_base = {
    'Мария Никитина': '+79033923029',
    'Егор Савичев': '+78125849204',
    'Александр Пахомов': '+79053049385',
    'Алина Егорова': '+79265748370',
    'Руслан Башаров': '+79030598495'
}
print(employee_base['Алина Егорова'])
