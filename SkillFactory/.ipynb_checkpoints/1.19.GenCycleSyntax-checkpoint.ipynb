# %%
#Представим, что нам нужно проверить на чётность все числа в диапазоне от 30 до 41 включительно 
#и вывести результат для каждого из них на экран.

for i in range(30, 42): # Условия для прохода по циклу
    # Тело цикла
    if i%2 == 0:
        print('Число', i, 'чётное')
    else:
        print('Число', i, 'нечётное')
# Out:
# Число 30 чётное
# Число 31 нечётное
# Число 32 чётное
# Число 33 нечётное
# Число 34 чётное
# Число 35 нечётное
# Число 36 чётное
# Число 37 нечётное
# Число 38 чётное
# Число 39 нечётное
# Число 40 чётное
# Число 41 нечётное

# %%
#Для получения диапазона для циклов часто используется функция range()
#и функция enumerate(), которая возвращает пары вида «счётчик-элемент». Её можно применять, например, к строкам. 

#Важно!
#По умолчанию нижняя граница диапазона в функции range() равна 0, а не 1, а указанная верхняя граница не включается.

#Пример				Соответствующий диапазон
#range(10)			от 0 до 9
#range(1, 10)		от 1 до 9
#range(1, 10, 2)	от 1 до 9 с шагом 2, т.е. 1, 3, 5, 7, 9

for i, letter in enumerate('Привет!'):
    #Здесь i - номер итерации (начиная с 0), а letter - символ с номером i из строки 'Привет!'
    print(i, letter)
    
#Здесь:
#0	П
#1	р
#...
#6	!
# Out:
# 0 П
# 1 р
# 2 и
# 3 в
# 4 е
# 5 т
# 6 !

# %%
#I – параметр (счетчик) цикла, A начальное значение параметра, B – его конечное значение, а N – шаг цикла (приращение счетчика). 
#Особенность реализации цикла for в python в том, что в качестве модифицирующего выражения используется функция range(). 
#Синтаксис цикла for:
# for target_list in expression_list:
#    Тело цикла
# [else:
#    Выражение]
#Где target_list – параметр цикла, 
#а expression_list – имя последовательности (например, списка) или вызов функции range(). 
#Также как и цикл while, for имеет необязательный блок else.
#Помимо обхода элементов коллекции, цикл for может применяться и в тех задачах, 
#когда, прежде выполнения инструкций тела цикла, становится известным (или заранее определено) количество шагов этого цикла.

# %%
#Задание 1

#Друзья придумали свой шифр: исходные слова заменять на последовательность нечётных символов в этих словах. 
#Например, 'python' в их шифровке будет выглядеть как 'pto'. 
#Напишите программу, которая помогает зашифровывать слова по этой схеме: 
#принимает на вход слово (word) и последовательно выводит каждый нечётный символ в нём. 
#Для проверки используйте word = 'подшипник'

#word = str(input())
word = 'подшипник'
cipher=''
for i, letter in enumerate(word):
    if i%2==0:
        cipher+=letter
print(cipher)
# Out:
# пдинк

# %%
#Задание 1
#Кретины

#word = str(input())
word = 'подшипник'
for i, letter in enumerate(word):
    if i%2==0:
        print(letter)
# Out:
# п
# д
# и
# н
# к

# %%
#Задание 2

#Вы решили написать программу, которая выявляет високосные года в диапазоне лет. 
#Пусть она принимает на вход два числа: нижнюю и верхнюю границы годов (переменные year_1 и year_2), 
#и для каждого года из диапазона выводит информацию: "... год високосный" или "... год невисокосный", 
#где вместо многоточия указывается номер года.
#Для проверки используйте year_1 = 2013, year_2 = 2020. Значения обеих переменных должны быть включены в диапазон.

year_1 = 2013
year_2 = 2020
for year in range(year_1, year_2+1):
    if year%4==0:
        print(year,'год високосный')
    else:
        print(year,'год невисокосный')
# Out:
# 2013 год невисокосный
# 2014 год невисокосный
# 2015 год невисокосный
# 2016 год високосный
# 2017 год невисокосный
# 2018 год невисокосный
# 2019 год невисокосный
# 2020 год високосный

# %%
#Задание 3

#Напишите программу, которая принимает на вход слово (word) и последовательно выводит все русские гласные из этого слова. 
#Для проверки используйте word = 'Зимушка-зима'

#word = str(input())
word = 'Зимушка-зима'
for i, letter in enumerate(word):
      if letter in 'АаЕеЁёИиОоУуЫыЭэЮюЯя':
        print(letter)
# Out:
# и
# у
# а
# и
# а

# %%
#Задание 4

#Попросите пользователя ввести своё имя (name) и с помощью цикла выведите каждую букву этого имени на экран, 
#сопроводив порядковым номером с помощью фразы: "Буква ... в этом имени - ..." (например, "Буква 1 в этом имени - С"). 
#Для проверки используйте name = 'Сергей'

#name = str(input())
name = 'Сергей'
for i, letter in enumerate(name):
    print('Буква',i+1,'в этом имени -',letter)
# Out:
# Буква 1 в этом имени - С
# Буква 2 в этом имени - е
# Буква 3 в этом имени - р
# Буква 4 в этом имени - г
# Буква 5 в этом имени - е
# Буква 6 в этом имени - й

# %%
#Задание 5

#Напишите программу, которая последовательно выводит нечётные числа, которые делятся на 3 или 5, 
#от первого введённого числа (num_1) до второго введённого числа (num_2) включительно. 
#Если второе число меньше первого или первое число меньше нуля, выведите "Введён неверный диапазон чисел".
#Для проверки используйте num_1 = 25, num_2 = 45

num_1 = int(input())
num_2 = int(input())
#num_1 = 25
#num_2 = 45
if num_1<0 or num_2<num_1:
    print('Введён неверный диапазон чисел')
