# %%
2.10 Обращение к ключам словаря

При обращении к ключу словаря этот ключ должен обязательно быть в словаре. Иначе мы получим ошибку. 
Попробуем обратиться к несуществующему ключу в нашем словаре employee_base:

employee_base['несуществующий сотрудник']
...
KeyError:'несуществующий сотрудник'

Такие ситуации часто возникают, если нужно пробежаться по списку значений и достать необходимую информацию из словаря. 
Например, приходит запрос: предоставьте контактные данные сотрудников из списка:

request = ['Мария Никитина', 'Егор Савичев', 'Алексей Чернышевский']
Для решения задачи мы создаем простой цикл прохода по именам сотрудников из списка request:

for name in request:
В каждом шаге цикла в name будет подставляться имя сотрудника.

Затем добавляем их поиск в словаре контактов employee_base 
(т. е. обращение к словарю employee_base по ключу name с именем сотрудника). 

for name in request:
    print(employee_base[name])
Контакты Марии и Егора алгоритм выводит на экран успешно. А вот для нового сотрудника Алексея, 
которого еще не успели внести в базу, цикл упадет с ошибкой. Т. к. в словаре employee_base его нет:

    ...
KeyError:'Алексей Чернышевский'

Для работы с такими ситуациями есть два стандартных способа. [в след. ноутбуке]
