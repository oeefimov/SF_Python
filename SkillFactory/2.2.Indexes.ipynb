# %%
Итак, список создан, и нам не терпится начать работать с его элементами. 
Прежде всего мы должны научиться извлекать элементы списка по их порядковому номеру. 
Порядковый номер элемента списка называется индекс.

______________________

Важно!

В Python, как и во многих других языках программирования, индексация элементов списка начинается не с единицы, а с нуля. 
Таким образом, самый первый элемент списка имеет индекс [0].

______________________

Для обращения к элементу списка необходимо указать имя переменной, в которой хранится список, 
а далее в квадратных скобках указать индекс нужного элемента. 
Например, в созданном на предыдущем шаге списке animals, 
элемент с индексом [0] — это кошка; с индексом 2 — хомяк, с индексом 3 — морская свинка.

Попробуйте повторно создать данный список и поэкспериментировать с его элементами:

animals = ['кошка', 'собака', 'хомяк', 'морская свинка', 'попугай', 'лошадь']
print(animals[0])
print(animals[2])
print(animals[3])

# %%
animals = ['кошка', 'собака', 'хомяк', 'морская свинка', 'попугай', 'лошадь']
print(animals[0])
print(animals[2])
print(animals[3])
# Out:
# кошка
# хомяк
# морская свинка

# %%
Списки можно читать не только слева направо, но и справа налево. 
Для того, чтобы обратиться к элементу списка, просматривая его содержимое в обратном порядке, 
мы можем использовать так называемую отрицательную индексацию. 
При использовании отрицательных индексов самый последний элемент списка будет иметь индекс [-1], предпоследний — [-2], и так далее.

Важно!

При использовании отрицательной индексации первый элемент справа имеет индекс [-1], а не [-0], 
т.к. число 0 не может быть положительным или отрицательным. 

Таким образом, правило о начале индексации с нуля применимо только в случае нумерации элементов слева направо. 
Давайте поэкспериментируем со списком animals, извлекая из него названия животных с помощью отрицательных индексов.

# %%
animals = ['кошка', 'собака', 'хомяк', 'морская свинка', 'попугай', 'лошадь']
print(animals[-1])
print(animals[-2])
print(animals[-6])
# Out:
# лошадь
# попугай
# кошка

# %%
А теперь — тренировка!
Для всех заданий, которые будут предложены вам ниже, мы составили список из имён наиболее выдающихся студентов SkillFactory 
за все время существования нашей школы. Если вы обнаружили своё имя в списке, — это не ошибка. 
Это означает, что мы увидели ваш потенциал и добавили имя заранее, чтобы  не переписывать материалы курса. :) 
Если вашего имени в списке пока нет, пожалуйста, держите ситуацию под контролем. 
Мы обязательно внесём все изменения, как только вы закончите обучение.

OurBestStudents = ['Александр', 'Константин', 'Мария', 'Диана', 'Алексей', 
                   'Максим', 'Светлана', 'Арина', 'Серафим', 'Doomer', 
                   'Павел', 'Виктория', 'Елена', 'Галина', 'Вячеслав']
______________________

Важно!

В некоторых заданиях этого шага вам нужно будет написать код для извлечения указанного элемента. 
Код нужно будет писать в одну строку без пробелов. Не забывайте указывать имя переменной. 
Также обращайте внимание на то, какой индекс (положительный или отрицательный) требуется использовать в условии задания.

# %%
#Задание 1

#Напишите код, который нужно передать в функцию print, чтобы извлечь из списка OurBestStudents имя "Александр". 
#Используйте положительную индексацию (слева направо).

OurBestStudents = ['Александр', 'Константин', 'Мария', 'Диана', 'Алексей', 
                   'Максим', 'Светлана', 'Арина', 'Серафим', 'Doomer', 
                   'Павел', 'Виктория', 'Елена', 'Галина', 'Вячеслав']
print(OurBestStudents[0])

#OurBestStudents[0]
# Out:
# Александр

# %%
#Задание 2

#Напишите код, с помощью которого можно извлечь из списка OurBestStudents имя "Мария". 
#Используйте положительную индексацию (слева направо)
#КРЕТИНЫ. "Правильный" ответ: OurBestStudents[2]

OurBestStudents = ['Александр', 'Константин', 'Мария', 'Диана', 'Алексей', 
                   'Максим', 'Светлана', 'Арина', 'Серафим', 'Doomer', 
                   'Павел', 'Виктория', 'Елена', 'Галина', 'Вячеслав']
print(OurBestStudents[2])
# Out:
# Мария

# %%
#Задание 3

#Напишите код, с помощью которого можно извлечь из списка OurBestStudents имя "Вячеслав". 
#Используйте отрицательную индексацию (справа налево)

OurBestStudents = ['Александр', 'Константин', 'Мария', 'Диана', 'Алексей', 
                   'Максим', 'Светлана', 'Арина', 'Серафим', 'Doomer', 
                   'Павел', 'Виктория', 'Елена', 'Галина', 'Вячеслав']
print(OurBestStudents[-1])
# Out:
# Вячеслав

# %%
#Задание 4

#Напишите код, с помощью которого можно извлечь из списка OurBestStudents имя "Вячеслав". 
#Используйте положительную индексацию (слева направо)

OurBestStudents = ['Александр', 'Константин', 'Мария', 'Диана', 'Алексей', 
                   'Максим', 'Светлана', 'Арина', 'Серафим', 'Doomer', 
                   'Павел', 'Виктория', 'Елена', 'Галина', 'Вячеслав']
print(OurBestStudents[14])
# Out:
# Вячеслав

# %%
#Задание 5

#Напишите код, с помощью которого можно извлечь из списка OurBestStudents имя "Арина". 
#Используйте отрицательную индексацию (справа налево)

OurBestStudents = ['Александр', 'Константин', 'Мария', 'Диана', 'Алексей', 
                   'Максим', 'Светлана', 'Арина', 'Серафим', 'Doomer', 
                   'Павел', 'Виктория', 'Елена', 'Галина', 'Вячеслав']
print(OurBestStudents[-8])
# Out:
# Арина
